# %%
import pandas as pd
from datetime import datetime
import os, sys
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import TimeoutException, NoSuchElementException, JavascriptException
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.support.ui import WebDriverWait, Select

# %%
# executable_path = r"C:\Users\817932702\mamikos\chromedriver\120\chromedriver.exe"
executable_path = r"D:\proyek\chromedriver\120\chromedriver.exe"
service = Service(executable_path)

options = webdriver.ChromeOptions()
options.add_argument("--disable-blink-features=AutomationControlled")
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option("useAutomationExtension", False) 
options.add_argument('--ignore-certificate-errors')
driver = webdriver.Chrome(service=service, options=options)

# %%
driver.get("https://mamikos.com/")

# %%
cari = driver.find_element(By. XPATH, '//*[@id="home"]/div[4]/div/div/div/div[1]')
cari.click()

# %%
area = driver.find_element(By. XPATH, '//*[@id="home"]/div[13]/div/div[2]/div[2]/ul/li[2]/a')
area.click()

# %%
kota = driver.find_element(By. XPATH, '//*[@id="home"]/div[13]/div/div[2]/div[4]/div/div[25]/details/summary')
kota.click()

# %%
kota_2 = driver.find_element(By. XPATH, '//*[@id="home"]/div[13]/div/div[2]/div[4]/div/div[25]/details/div/a[5]')
kota_2.click()

# %%
kost = driver.find_element(By. XPATH, '//*[@id="app"]/div/div[5]/div/div[1]/div/div/div[1]/div[1]/div[1]')
isi_elemen = kost.text

data_elemen = isi_elemen.split('\n')

# Buat DataFrame
df = pd.DataFrame({
    'Jenis': [data_elemen[0]],
    'Status Kamar': [data_elemen[1]],
    'Nama Kost': [data_elemen[2]],
    'Lokasi': [data_elemen[3]],
    'Fasilitas': [data_elemen[4]],
    'Rating': [data_elemen[5]],
    'Diskon': [data_elemen[6]],
    'Harga': [data_elemen[7]]
})

# Tampilkan DataFrame
print(df)
# Out:
#     Jenis  Status Kamar                                          Nama Kost
# 0  Campur  Sisa 1 kamar  Kost Apik Pondok Jaya VIII Tipe C Mampang Prap...  \
#
#              Lokasi                                Fasilitas Rating
# 0  Mampang Prapatan  WiFi ·Kloset Duduk ·Kasur ·Akses 24 Jam    4.6  \
#
#                       Diskon        Harga
# 0  Diskon 200rb sewa 3 bulan  Rp1.325.000

# %%
# Inisialisasi list untuk menyimpan DataFrames
list_df = []

# Lakukan perulangan untuk nomor 1 hingga 20
for i in range(1, 21):
    # Bangun XPath berdasarkan nomor iterasi
    xpath = '//*[@id="app"]/div/div[5]/div/div[1]/div/div/div[1]/div[1]/div[' + str(i) + ']'
    
    try:
        # Temukan elemen dengan XPath
        elemen = driver.find_element(By.XPATH, xpath)

        # Dapatkan teks dari elemen
        isi_elemen = elemen.text

        # Pisahkan teks menjadi kolom-kolom yang sesuai
        data_elemen = isi_elemen.split('\n')

        # Buat DataFrame
        df = pd.DataFrame({
            'Jenis': [data_elemen[0]],
            'Status Kamar': [data_elemen[1]] if len(data_elemen) > 1 else None,
            'Nama Kost': [data_elemen[2]] if len(data_elemen) > 1 else None,
            'Lokasi': [data_elemen[3]],
            'Fasilitas': [data_elemen[4]],
            'Rating': [data_elemen[5]],
            'Diskon': [data_elemen[6]] if len(data_elemen) > 1 else None,  # Tambahkan penanganan untuk elemen yang tidak memiliki 'Diskon'
            'Harga': [data_elemen[7]]
        })

        # Tambahkan DataFrame ke dalam list
        list_df.append(df)
    except:
        # Tangani kesalahan jika elemen tidak ditemukan
        print(f"Elemen dengan XPath {xpath} tidak ditemukan.")

# Gabungkan semua DataFrames menjadi satu
final_df = pd.concat(list_df, ignore_index=True)

# Tampilkan DataFrame
print(final_df)
# Out:
# Elemen dengan XPath //*[@id="app"]/div/div[5]/div/div[1]/div/div/div[1]/div[1]/div[19] tidak ditemukan.
# Elemen dengan XPath //*[@id="app"]/div/div[5]/div/div[1]/div/div/div[1]/div[1]/div[20] tidak ditemukan.
#           Jenis                                       Status Kamar
# 0        Campur                                       Sisa 1 kamar  \
# 1         Putri                                       Sisa 2 kamar
# 2         Putri                                       Sisa 1 kamar
# 3        Campur                                       Sisa 1 kamar
# 4         Putri                                       Sisa 1 kamar
# 5        Campur                                       Sisa 2 kamar
# 6        Campur                                       Sisa 1 kamar
# 7        Campur  Kost Singgahsini RR Mansion Tipe D Pancoran Ja...
# 8        Campur                                       Sisa 1 kamar
# 9        Campur                                       Sisa 3 kamar
# 10       Campur                                       Sisa 2 kamar
# 11        Putri                                       Sisa 1 kamar
# 12       Campur                                       Sisa 1 kamar
# 13       Campur                                       Sisa 1 kamar
# 14       Campur                                       Sisa 1 kamar
# 15        Putri                                       Sisa 1 kamar
# 16  Kos Andalan                                             Campur
# 17  Kos Andalan                                             Campur
#
#                                             Nama Kost
# 0   Kost Apik Pondok Jaya VIII Tipe C Mampang Prap...  \
# 1   Kost Apik Evy Kalibata Utara Tipe A Pancoran J...
# 2   Kost Apik Pondok Jaya 21A Tipe C Mampang Prapa...
# 3   Kost Singgahsini Richie Bangka Barat IV Tipe A...
# 4   Kost Singgahsini Tegal Parang Tipe B Mampang P...
# 5   Kost Singgahsini Nathan Kemang Utara Tipe B Ma...
# 6   Kost Singgahsini Attahiriyah Pejaten Tipe A Pa...
# 7                                            Pancoran
# 8   Kost Singgahsini RR Mansion Tipe E Pancoran Ja...
# 9   Kost Singgahsini RR Mansion Tipe C Pancoran Ja...
# 10  Kost Singgahsini RR Mansion Tipe B Pancoran Ja...
# 11  Kost Singgahsini White House Tipe A Mampang Pr...
# 12  Kost Singgahsini Vit Tipe B Mampang Prapatan J...
# 13  Kost Singgahsini Nathan Kemang Utara Tipe A Ma...
# 14  Kost Singgahsini RR Mansion Tipe A Pancoran Ja...
# 15  Kost Singgahsini White House Tipe B Mampang Pr...
# 16  Kost Harum 1 Tipe A Kebayoran Baru Jakarta Sel...
# 17  Kost Senopati SCBD Jamsostek Gatot Subroto Tip...
#
#                                                Lokasi
# 0                                    Mampang Prapatan  \
# 1                                            Pancoran
# 2                                    Mampang Prapatan
# 3                                    Mampang Prapatan
# 4                          Kecamatan Mampang Prapatan
# 5                                    Mampang Prapatan
# 6                                        Pasar Minggu
# 7   K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ...
# 8                                            Pancoran
# 9                                            Pancoran
# 10                                           Pancoran
# 11                         Kecamatan Mampang Prapatan
# 12                                   Mampang Prapatan
# 13                                   Mampang Prapatan
# 14                                           Pancoran
# 15                         Kecamatan Mampang Prapatan
# 16                           Kecamatan Kebayoran Baru
# 17                           Kecamatan Kebayoran Baru
#
#                                             Fasilitas        Rating
# 0             WiFi ·Kloset Duduk ·Kasur ·Akses 24 Jam           4.6  \
# 1           K. Mandi Dalam ·WiFi ·Kasur ·Akses 24 Jam           4.9
# 2             WiFi ·Kloset Duduk ·Kasur ·Akses 24 Jam           4.6
# 3   K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ...           4.9
# 4   K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ...           4.9
# 5   K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ...           4.4
# 6   K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ...           4.9
# 7                                        Diskon 200rb   Rp3.925.000
# 8   K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ...           5.0
# 9   K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ...  Diskon 200rb
# 10  K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ...  Diskon 200rb
# 11  K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ...           4.6
# 12  K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ...  Diskon 200rb
# 13  K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ...  Diskon 200rb
# 14  K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ...  Diskon 200rb
# 15  K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ...           4.6
# 16                                Kasur ·Akses 24 Jam           5.0
# 17  K. Mandi Dalam ·WiFi ·Kloset Duduk ·Kasur ·Aks...   Rp1.100.000
#
#                            Diskon            Harga
# 0       Diskon 200rb sewa 3 bulan      Rp1.325.000
# 1       Diskon 200rb sewa 3 bulan      Rp1.375.000
# 2       Diskon 200rb sewa 3 bulan      Rp1.625.000
# 3       Diskon 250rb sewa 3 bulan      Rp2.225.000
# 4       Diskon 250rb sewa 3 bulan      Rp2.875.000
# 5                    Diskon 200rb      Rp2.925.000
# 6                     Diskon 75rb      Rp2.005.000
# 7                     Rp3.725.000  (Bulan pertama)
# 8                    Diskon 150rb      Rp3.625.000
# 9                     Rp4.275.000      Rp4.075.000
# 10                    Rp4.475.000      Rp4.275.000
# 11                   Diskon 200rb      Rp2.605.000
# 12                    Rp3.825.000      Rp3.625.000
# 13                    Rp3.425.000      Rp3.225.000
# 14                    Rp5.025.000      Rp4.825.000
# 15  Ngekos di SS SatSet Gak Macet      Rp2.805.000
# 16                      Rp650.000           /bulan
# 17                         /bulan            Penuh

# %%
from IPython.display import display
display(final_df)
# Out:
#           Jenis                                       Status Kamar  \
# 0        Campur                                       Sisa 1 kamar
# 1         Putra                                       Sisa 1 kamar
# 2         Putri                                       Sisa 2 kamar
# 3        Campur                                       Sisa 1 kamar
# 4         Putri                                       Sisa 1 kamar
# 5        Campur                                       Sisa 1 kamar
# 6        Campur  Kost Singgahsini RR Mansion Tipe D Pancoran Ja...
# 7        Campur                                       Sisa 1 kamar
# 8        Campur                                       Sisa 3 kamar
# 9        Campur                                       Sisa 2 kamar
# 10       Campur                                       Sisa 1 kamar
# 11       Campur                                       Sisa 1 kamar
# 12       Campur                                       Sisa 1 kamar
# 13        Putri                                       Sisa 1 kamar
# 14  Kos Andalan                                             Campur
# 15  Kos Andalan                                              Putri
#
#                                             Nama Kost  \
# 0   Kost Apik Pondok Jaya VIII Tipe C Mampang Prap...
# 1   Kost Singgahsini Casa Kalasa Tipe B Mampang Pr...
# 2   Kost Apik Evy Kalibata Utara Tipe A Pancoran J...
# 3   Kost Singgahsini Richie Bangka Barat IV Tipe A...
# 4   Kost Singgahsini White House Tipe A Mampang Pr...
# 5   Kost Singgahsini Attahiriyah Pejaten Tipe A Pa...
# 6                                            Pancoran
# 7   Kost Singgahsini RR Mansion Tipe E Pancoran Ja...
# 8   Kost Singgahsini RR Mansion Tipe C Pancoran Ja...
# 9   Kost Singgahsini RR Mansion Tipe B Pancoran Ja...
# 10  Kost Singgahsini Nathan Kemang Utara Tipe A Ma...
# 11  Kost Singgahsini Vit Tipe B Mampang Prapatan J...
# 12  Kost Singgahsini RR Mansion Tipe A Pancoran Ja...
# 13  Kost Singgahsini White House Tipe B Mampang Pr...
# 14  Kost Ekslusif Edomora Residence Kebayoran Baru...
# 15  Kost Adimas Tipe B Mampang Prapatan Jakarta Se...
#
#                                              Lokasi  \
# 0                                  Mampang Prapatan
# 1                                  Mampang Prapatan
# 2                                          Pancoran
# 3                                  Mampang Prapatan
# 4                        Kecamatan Mampang Prapatan
# 5                                      Pasar Minggu
# 6   K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ·
# 7                                          Pancoran
# 8                                          Pancoran
# 9                                          Pancoran
# 10                                 Mampang Prapatan
# 11                                 Mampang Prapatan
# 12                                         Pancoran
# 13                       Kecamatan Mampang Prapatan
# 14                         Kecamatan Kebayoran Baru
# 15                       Kecamatan Mampang Prapatan
#
#                                           Fasilitas        Rating  \
# 0           WiFi ·Kloset Duduk ·Kasur ·Akses 24 Jam           4.6
# 1   K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ·           4.9
# 2         K. Mandi Dalam ·WiFi ·Kasur ·Akses 24 Jam           4.9
# 3   K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ·           4.9
# 4   K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ·           4.6
# 5   K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ·           4.9
# 6                                      Diskon 200rb   Rp3.925.000
# 7   K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ·           5.0
# 8   K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ·  Diskon 200rb
# 9   K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ·  Diskon 200rb
# 10  K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ·  Diskon 200rb
# 11  K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ·  Diskon 200rb
# 12  K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ·  Diskon 200rb
# 13  K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ·           4.6
# 14  K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ·           5.0
# 15                              Kasur ·Akses 24 Jam           4.6
#
#                            Diskon            Harga
# 0       Diskon 200rb sewa 3 bulan      Rp1.325.000
# 1       Diskon 250rb sewa 3 bulan      Rp2.675.000
# 2       Diskon 200rb sewa 3 bulan      Rp1.375.000
# 3       Diskon 250rb sewa 3 bulan      Rp2.225.000
# 4                    Diskon 200rb      Rp2.605.000
# 5                     Diskon 75rb      Rp2.005.000
# 6                     Rp3.725.000  (Bulan pertama)
# 7                    Diskon 150rb      Rp3.625.000
# 8                     Rp4.275.000      Rp4.075.000
# 9                     Rp4.475.000      Rp4.275.000
# 10                    Rp3.425.000      Rp3.225.000
# 11                    Rp3.825.000      Rp3.625.000
# 12                    Rp5.025.000      Rp4.825.000
# 13  Ngekos di SS SatSet Gak Macet      Rp2.805.000
# 14                    Rp3.600.000           /bulan
# 15                      Rp800.000           /bulan

# %%
final_df.to_csv('mamikos_.csv', index=False)

# %%
next_button = driver.find_element(By. XPATH, '//*[@id="app"]/div/div[5]/div/div[1]/div/div/div[1]/div[2]/div/a')
next_button.click()

# %%
import pandas as pd
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException

# Inisialisasi list untuk menyimpan DataFrames
list_df = []

# Buat perulangan tak terbatas
while True:
    # Lakukan perulangan untuk nomor 1 hingga 20
    for i in range(1, 21):
        # Bangun XPath berdasarkan nomor iterasi
        xpath = '//*[@id="app"]/div/div[5]/div/div[1]/div/div/div[1]/div[1]/div[' + str(i) + ']'

        try:
            # Temukan elemen dengan XPath
            elemen = driver.find_element(By.XPATH, xpath)

            # Dapatkan teks dari elemen
            isi_elemen = elemen.text

            # Pisahkan teks menjadi kolom-kolom yang sesuai
            data_elemen = isi_elemen.split('\n')

            # Buat DataFrame
            df = pd.DataFrame({
                'Jenis': [data_elemen[0]],
                'Status Kamar': [data_elemen[1]] if len(data_elemen) > 1 else None,
                'Nama Kost': [data_elemen[2]] if len(data_elemen) > 1 else None,
                'Lokasi': [data_elemen[3]],
                'Fasilitas': [data_elemen[4]],
                'Rating': [data_elemen[5]],
                'Diskon': [data_elemen[6]] if len(data_elemen) > 1 else None,
                'Harga': [data_elemen[7]]
            })

            # Tambahkan DataFrame ke dalam list
            list_df.append(df)
        except NoSuchElementException:
            # Tangani kesalahan jika elemen tidak ditemukan
            print(f"Elemen dengan XPath {xpath} tidak ditemukan.")

    try:
        # Temukan tombol "Next" dan klik
        next_button = driver.find_element(By.XPATH, '//*[@id="app"]/div/div[5]/div/div[1]/div/div/div[1]/div[2]/div/a')
        next_button.click()
    except NoSuchElementException:
        # Tangani kesalahan jika tombol "Next" tidak ditemukan, akhiri perulangan
        print("Tidak ada tombol 'Next' yang ditemukan. Scraping selesai.")
        break

# Gabungkan semua DataFrames menjadi satu
final_df = pd.concat(list_df, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[11], line 34
#      23 data_elemen = isi_elemen.split('\n')
#      25 # Buat DataFrame
#      26 df = pd.DataFrame({
#      27     'Jenis': [data_elemen[0]],
#      28     'Status Kamar': [data_elemen[1]] if len(data_elemen) > 1 else None,
#      29     'Nama Kost': [data_elemen[2]] if len(data_elemen) > 1 else None,
#      30     'Lokasi': [data_elemen[3]],
#      31     'Fasilitas': [data_elemen[4]],
#      32     'Rating': [data_elemen[5]],
#      33     'Diskon': [data_elemen[6]] if len(data_elemen) > 1 else None,
# ---> 34     'Harga': [data_elemen[7]]
#      35 })
#      37 # Tambahkan DataFrame ke dalam list
#      38 list_df.append(df)
#
# IndexError: list index out of range

# %%
import pandas as pd
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
import time

# Inisialisasi list untuk menyimpan DataFrames
list_df = []

# Buat perulangan tak terbatas
while True:
    # Bangun XPath untuk semua elemen di halaman saat ini
    xpath_base = '//*[@id="app"]/div/div[5]/div/div[1]/div/div/div[1]/div[1]/div'
    
    # Temukan semua elemen menggunakan XPath yang umum
    elements = driver.find_elements(By.XPATH, xpath_base)

    # Jika tidak ada elemen yang ditemukan, berhenti dari perulangan
    if not elements:
        print("Tidak ada elemen yang ditemukan. Scraping selesai.")
        break

    # Iterasi melalui semua elemen yang ditemukan di halaman saat ini
    for element in elements:
        try:
            # Dapatkan teks dari elemen
            isi_elemen = element.text

            # Pisahkan teks menjadi kolom-kolom yang sesuai
            data_elemen = isi_elemen.split('\n')

            # Buat DataFrame
            df = pd.DataFrame({
                'Jenis': [data_elemen[0]],
                'Status Kamar': [data_elemen[1]] if len(data_elemen) > 1 else None,
                'Nama Kost': [data_elemen[2]] if len(data_elemen) > 1 else None,
                'Lokasi': [data_elemen[3]],
                'Fasilitas': [data_elemen[4]],
                'Rating': [data_elemen[5]],
                'Diskon': [data_elemen[6]] if len(data_elemen) > 1 else None,
                'Harga': [data_elemen[7]]
            })

            # Tambahkan DataFrame ke dalam list
            list_df.append(df)
        except NoSuchElementException:
            # Tangani kesalahan jika elemen tidak ditemukan
            print("Elemen tidak ditemukan.")

    try:
        # Temukan tombol "Next" dan klik
        next_button = driver.find_element(By.XPATH, '//*[@id="app"]/div/div[5]/div/div[1]/div/div/div[1]/div[2]/div/a')
        next_button.click()
    except NoSuchElementException:
        # Tangani kesalahan jika tombol "Next" tidak ditemukan, akhiri perulangan
        print("Tidak ada tombol 'Next' yang ditemukan. Scraping selesai.")
        break

    # Tambahkan penundaan (delay) jika diperlukan sebelum melakukan scraping halaman berikutnya
    time.sleep(2)  # Sesuaikan dengan kebutuhan Anda

# Gabungkan semua DataFrames menjadi satu
final_df = pd.concat(list_df, ignore_index=True)
