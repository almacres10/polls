# %%
import pandas as pd
from datetime import datetime
import os, sys
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import TimeoutException, NoSuchElementException, JavascriptException
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.support.ui import WebDriverWait, Select

# %%
executable_path = r"D:\proyek\scrapper\chromedriver\120\chromedriver.exe"
service = Service(executable_path)

options = webdriver.ChromeOptions()
options.add_argument("--disable-blink-features=AutomationControlled")
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option("useAutomationExtension", False) 
options.add_argument('--ignore-certificate-errors')
driver = webdriver.Chrome(service=service, options=options)

# %%
driver.get("https://mamikos.com/")

# %%
cari = driver.find_element(By. XPATH, '//*[@id="home"]/div[5]/div/div/div/div[1]')
cari.click()

# %%
area = driver.find_element(By. XPATH, '//*[@id="home"]/div[13]/div/div[2]/div[2]/ul/li[2]/a')
area.click()

# %%
kota = driver.find_element(By. XPATH, '//*[@id="home"]/div[13]/div/div[2]/div[4]/div/div[25]/details/summary')
kota.click()

# %%
kota_2 = driver.find_element(By. XPATH, '//*[@id="home"]/div[13]/div/div[2]/div[4]/div/div[25]/details/div/a[5]')
kota_2.click()

# %%
kost = driver.find_element(By. XPATH, '//*[@id="app"]/div/div[5]/div/div[1]/div/div/div[1]/div[1]/div[1]')
isi_elemen = kost.text

data_elemen = isi_elemen.split('\n')

# Buat DataFrame
df = pd.DataFrame({
    'Jenis': [data_elemen[0]],
    'Status Kamar': [data_elemen[1]],
    'Nama Kost': [data_elemen[2]],
    'Lokasi': [data_elemen[3]],
    'Fasilitas': [data_elemen[4]],
    'Rating': [data_elemen[5]],
    'Diskon': [data_elemen[6]],
    'Harga': [data_elemen[7]]
})

# Tampilkan DataFrame
print(df)
# Out:
#     Jenis  Status Kamar                                          Nama Kost  \
# 0  Campur  Sisa 1 kamar  Kost Singgahsini Kemang Timur Syariah Tipe C M...
#
#              Lokasi                                          Fasilitas Rating  \
# 0  Mampang Prapatan  K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ...    4.6
#
#                       Diskon        Harga
# 0  Diskon 250rb sewa 3 bulan  Rp2.125.000

# %%
from IPython.display import display
display(final_df)
# Out:
#           Jenis                                       Status Kamar  \
# 0        Campur                                       Sisa 1 kamar
# 1        Campur                                       Sisa 1 kamar
# 2        Campur                                       Sisa 1 kamar
# 3        Campur                                       Sisa 1 kamar
# 4        Campur                                       Sisa 1 kamar
# 5        Campur                                       Sisa 2 kamar
# 6        Campur                                       Sisa 1 kamar
# 7        Campur  Kost Singgahsini RR Mansion Tipe D Pancoran Ja...
# 8        Campur                                       Sisa 3 kamar
# 9         Putri                                       Sisa 1 kamar
# 10       Campur                                       Sisa 1 kamar
# 11       Campur                                       Sisa 1 kamar
# 12       Campur                                       Sisa 1 kamar
# 13        Putri                                       Sisa 1 kamar
# 14        Putri                                       Sisa 2 kamar
# 15  Kos Andalan                                             Campur
#
#                                             Nama Kost  \
# 0   Kost Singgahsini Kemang Timur Syariah Tipe C M...
# 1   Kost Singgahsini Griya Batang Agam Tipe B Panc...
# 2   Kost Apik Pondok Jaya VIII Tipe A Mampang Prap...
# 3   Kost Singgahsini Attahiriyah Pejaten Tipe B Pa...
# 4   Kost Singgahsini Richie Bangka Barat IV Tipe A...
# 5   Kost Singgahsini RR Mansion Tipe B Pancoran Ja...
# 6   Kost Singgahsini RR Mansion Tipe E Pancoran Ja...
# 7                                            Pancoran
# 8   Kost Singgahsini RR Mansion Tipe C Pancoran Ja...
# 9   Kost Singgahsini White House Tipe A Mampang Pr...
# 10  Kost Singgahsini Nathan Kemang Utara Tipe A Ma...
# 11  Kost Singgahsini Vit Tipe B Mampang Prapatan J...
# 12  Kost Singgahsini RR Mansion Tipe A Pancoran Ja...
# 13  Kost Singgahsini White House Tipe B Mampang Pr...
# 14  Kost Singgahsini White House Tipe C Mampang Pr...
# 15  Kost Bangka 2 Tipe VVIP Mampang Prapatan Jakar...
#
#                                                Lokasi  \
# 0                                    Mampang Prapatan
# 1                                            Pancoran
# 2                                    Mampang Prapatan
# 3                                        Pasar Minggu
# 4                                    Mampang Prapatan
# 5                                            Pancoran
# 6                                            Pancoran
# 7   K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ...
# 8                                            Pancoran
# 9                          Kecamatan Mampang Prapatan
# 10                                   Mampang Prapatan
# 11                                   Mampang Prapatan
# 12                                           Pancoran
# 13                         Kecamatan Mampang Prapatan
# 14                         Kecamatan Mampang Prapatan
# 15                                   Mampang Prapatan
#
#                                             Fasilitas  \
# 0   K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ...
# 1   K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ...
# 2         WiFi ·AC ·Kloset Duduk ·Kasur ·Akses 24 Jam
# 3   K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ...
# 4   K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ...
# 5   K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ...
# 6   K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ...
# 7                                        Diskon 200rb
# 8   K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ...
# 9   K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ...
# 10  K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ...
# 11  K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ...
# 12  K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ...
# 13  K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ...
# 14  K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ...
# 15        WiFi ·AC ·Kloset Duduk ·Kasur ·Akses 24 Jam
#
#                        Rating                     Diskon            Harga
# 0                         4.6  Diskon 250rb sewa 3 bulan      Rp2.125.000
# 1                         4.6  Diskon 250rb sewa 3 bulan      Rp2.625.000
# 2   Diskon 250rb sewa 3 bulan                Rp2.175.000           /bulan
# 3                         4.6               Diskon 100rb      Rp2.075.000
# 4                         4.9  Diskon 250rb sewa 3 bulan      Rp2.225.000
# 5                Diskon 200rb                Rp4.475.000      Rp4.275.000
# 6                         5.0               Diskon 150rb      Rp3.625.000
# 7                 Rp3.925.000                Rp3.725.000  (Bulan pertama)
# 8                Diskon 200rb                Rp4.275.000      Rp4.075.000
# 9                         4.6               Diskon 200rb      Rp2.605.000
# 10               Diskon 200rb                Rp3.425.000      Rp3.225.000
# 11               Diskon 200rb                Rp3.825.000      Rp3.625.000
# 12               Diskon 200rb                Rp5.025.000      Rp4.825.000
# 13                        4.6                Rp2.805.000           /bulan
# 14                        4.8                Rp3.115.000           /bulan
# 15                        5.0                Rp3.000.000           /bulan

# %%
# Inisialisasi list untuk menyimpan DataFrames
list_df = []

# Lakukan perulangan untuk nomor 1 hingga 20
for i in range(1, 21):
    # Bangun XPath berdasarkan nomor iterasi
    xpath = '//*[@id="app"]/div/div[5]/div/div[1]/div/div/div[1]/div[1]/div[' + str(i) + ']'
    
    try:
        # Temukan elemen dengan XPath
        elemen = driver.find_element(By.XPATH, xpath)

        # Dapatkan teks dari elemen
        isi_elemen = elemen.text

        # Pisahkan teks menjadi kolom-kolom yang sesuai
        data_elemen = isi_elemen.split('\n')

        # Buat DataFrame
        df = pd.DataFrame({
            'Jenis': [data_elemen[0]],
            'Status Kamar': [data_elemen[1]] if len(data_elemen) > 1 else None,
            'Nama Kost': [data_elemen[2]] if len(data_elemen) > 1 else None,
            'Lokasi': [data_elemen[3]],
            'Fasilitas': [data_elemen[4]],
            'Rating': [data_elemen[5]],
            'Diskon': [data_elemen[6]] if len(data_elemen) > 1 else None,  # Tambahkan penanganan untuk elemen yang tidak memiliki 'Diskon'
            'Harga': [data_elemen[7]]
        })

        # Tambahkan DataFrame ke dalam list
        list_df.append(df)
    except:
        # Tangani kesalahan jika elemen tidak ditemukan
        print(f"Elemen dengan XPath {xpath} tidak ditemukan.")

# Gabungkan semua DataFrames menjadi satu
final_df = pd.concat(list_df, ignore_index=True)

# Tampilkan DataFrame
print(final_df)
# Out:
# Elemen dengan XPath //*[@id="app"]/div/div[5]/div/div[1]/div/div/div[1]/div[1]/div[16] tidak ditemukan.
# Elemen dengan XPath //*[@id="app"]/div/div[5]/div/div[1]/div/div/div[1]/div[1]/div[18] tidak ditemukan.
# Elemen dengan XPath //*[@id="app"]/div/div[5]/div/div[1]/div/div/div[1]/div[1]/div[19] tidak ditemukan.
# Elemen dengan XPath //*[@id="app"]/div/div[5]/div/div[1]/div/div/div[1]/div[1]/div[20] tidak ditemukan.
#           Jenis                                       Status Kamar  \
# 0        Campur                                       Sisa 1 kamar
# 1        Campur                                       Sisa 1 kamar
# 2        Campur                                       Sisa 1 kamar
# 3        Campur                                       Sisa 1 kamar
# 4        Campur                                       Sisa 1 kamar
# 5        Campur                                       Sisa 2 kamar
# 6        Campur                                       Sisa 1 kamar
# 7        Campur  Kost Singgahsini RR Mansion Tipe D Pancoran Ja...
# 8        Campur                                       Sisa 3 kamar
# 9         Putri                                       Sisa 1 kamar
# 10       Campur                                       Sisa 1 kamar
# 11       Campur                                       Sisa 1 kamar
# 12       Campur                                       Sisa 1 kamar
# 13        Putri                                       Sisa 1 kamar
# 14        Putri                                       Sisa 2 kamar
# 15  Kos Andalan                                             Campur
#
#                                             Nama Kost  \
# 0   Kost Singgahsini Kemang Timur Syariah Tipe C M...
# 1   Kost Singgahsini Griya Batang Agam Tipe B Panc...
# 2   Kost Apik Pondok Jaya VIII Tipe A Mampang Prap...
# 3   Kost Singgahsini Attahiriyah Pejaten Tipe B Pa...
# 4   Kost Singgahsini Richie Bangka Barat IV Tipe A...
# 5   Kost Singgahsini RR Mansion Tipe B Pancoran Ja...
# 6   Kost Singgahsini RR Mansion Tipe E Pancoran Ja...
# 7                                            Pancoran
# 8   Kost Singgahsini RR Mansion Tipe C Pancoran Ja...
# 9   Kost Singgahsini White House Tipe A Mampang Pr...
# 10  Kost Singgahsini Nathan Kemang Utara Tipe A Ma...
# 11  Kost Singgahsini Vit Tipe B Mampang Prapatan J...
# 12  Kost Singgahsini RR Mansion Tipe A Pancoran Ja...
# 13  Kost Singgahsini White House Tipe B Mampang Pr...
# 14  Kost Singgahsini White House Tipe C Mampang Pr...
# 15  Kost Bangka 2 Tipe VVIP Mampang Prapatan Jakar...
#
#                                                Lokasi  \
# 0                                    Mampang Prapatan
# 1                                            Pancoran
# 2                                    Mampang Prapatan
# 3                                        Pasar Minggu
# 4                                    Mampang Prapatan
# 5                                            Pancoran
# 6                                            Pancoran
# 7   K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ...
# 8                                            Pancoran
# 9                          Kecamatan Mampang Prapatan
# 10                                   Mampang Prapatan
# 11                                   Mampang Prapatan
# 12                                           Pancoran
# 13                         Kecamatan Mampang Prapatan
# 14                         Kecamatan Mampang Prapatan
# 15                                   Mampang Prapatan
#
#                                             Fasilitas  \
# 0   K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ...
# 1   K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ...
# 2         WiFi ·AC ·Kloset Duduk ·Kasur ·Akses 24 Jam
# 3   K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ...
# 4   K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ...
# 5   K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ...
# 6   K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ...
# 7                                        Diskon 200rb
# 8   K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ...
# 9   K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ...
# 10  K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ...
# 11  K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ...
# 12  K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ...
# 13  K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ...
# 14  K. Mandi Dalam ·WiFi ·AC ·Kloset Duduk ·Kasur ...
# 15        WiFi ·AC ·Kloset Duduk ·Kasur ·Akses 24 Jam
#
#                        Rating                     Diskon            Harga
# 0                         4.6  Diskon 250rb sewa 3 bulan      Rp2.125.000
# 1                         4.6  Diskon 250rb sewa 3 bulan      Rp2.625.000
# 2   Diskon 250rb sewa 3 bulan                Rp2.175.000           /bulan
# 3                         4.6               Diskon 100rb      Rp2.075.000
# 4                         4.9  Diskon 250rb sewa 3 bulan      Rp2.225.000
# 5                Diskon 200rb                Rp4.475.000      Rp4.275.000
# 6                         5.0               Diskon 150rb      Rp3.625.000
# 7                 Rp3.925.000                Rp3.725.000  (Bulan pertama)
# 8                Diskon 200rb                Rp4.275.000      Rp4.075.000
# 9                         4.6               Diskon 200rb      Rp2.605.000
# 10               Diskon 200rb                Rp3.425.000      Rp3.225.000
# 11               Diskon 200rb                Rp3.825.000      Rp3.625.000
# 12               Diskon 200rb                Rp5.025.000      Rp4.825.000
# 13                        4.6                Rp2.805.000           /bulan
# 14                        4.8                Rp3.115.000           /bulan
# 15                        5.0                Rp3.000.000           /bulan
